# %%
from observation_mapper import *
import json

# %%
with open("collated_observations.json", "r") as obs_file:
    observations = json.load(obs_file)

# %%
for observation in observations:
    lake_name = observation["lake_name"] 
    if (lake_name != ""):
        result = find_best_matching_water_body(lake_name, observation["region_hint"])
        print(f"lake name {lake_name} ({observation["region_hint"]}), matched to:")
        print(result)
# Out:
# lake name Kibbie Lake (sierra nevada), matched to:
# [RealDictRow({'id': 23055, 'name': 'Kibbie Lake'})]
# lake name Redwood Creek (sierra nevada), matched to:
# []
# lake name Kern River (sierra nevada), matched to:
# [RealDictRow({'id': 26578, 'name': 'Kern River No. 26'}), RealDictRow({'id': 26586, 'name': 'Kern River No. 24'}), RealDictRow({'id': 26591, 'name': 'Kern River No. 21-23'}), RealDictRow({'id': 26593, 'name': 'Kern River No. 27'}), RealDictRow({'id': 26635, 'name': 'Kern River No. 19-20'}), RealDictRow({'id': 26640, 'name': 'Kern River No. 18'}), RealDictRow({'id': 26658, 'name': 'Kern River No. 15-17'}), RealDictRow({'id': 26660, 'name': 'Kern River No. 12'}), RealDictRow({'id': 26676, 'name': 'Kern River No. 10'}), RealDictRow({'id': 26681, 'name': 'Kern River No. 9'}), RealDictRow({'id': 26703, 'name': 'Kern River No. 1'}), RealDictRow({'id': 26706, 'name': 'Kern River No. 2'}), RealDictRow({'id': 27393, 'name': 'Kern River No. 3'})]
# ...
