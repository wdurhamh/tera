# %%
from nlp_parse import *
import json

# %%
batch_file_path = "processed_posts/hst_posts_1777437981.json"
out_file_test = "testing123.json"

# %%
process_batch_file(batch_file_path, out_file_test)
# Out:
# {
#   "observations": [
#     {
#       "lake_name": "Tyee Lake",
#       "species": null,
#       "count": null,
#       "length": null,
#       "date": null,
#       "nearby_landmarks": [],
#       "notes": "Fishing observed, but no catches reported."
#     }
#   ]
# }
# {"observations":[{"lake_name":"Burro Lake","species":"bk","count":null,"length":null,"date":"unknown","nearby_landmarks":["Virginia Lakes trailhead","Excelsior Mountain","Mary Lake","Cooney Lake","Frog Lake","Little Tween Lakes"],"notes":"The lake showed signs of a total fish kill-off; previously abundant small brookies were absent."}]}
# bk
# ...

# %%
with open(out_file_test) as f:
    results = json.load(f)
results
